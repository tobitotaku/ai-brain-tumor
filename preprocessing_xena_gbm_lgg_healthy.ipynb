# %% [markdown]
# # Preprocessing

# %% [markdown]
# Import python modules

# %%
import pandas as pd
import numpy as np
import pycombat
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# ## Load gene expression and metadata

# %%
import_expression_filepath = "data/processed/expression_brain_only.csv" 
import_metadata_filepath = "data/processed/metadata_brain_only.csv"
export_expression_filepath = "data/processed/expression_gbm_lgg_healthy.csv" 
export_metadata_filepath = "data/processed/metadata_gbm_lgg_healthy.csv"

# %%
gene_expression_df = pd.read_csv(
    import_expression_filepath,
    # index_col='sample_id'
)
print("Expression Shape:", gene_expression_df.shape)
display(gene_expression_df.head())
# Out:
# Expression Shape: (60498, 1840)
#          sample_id  TCGA-19-1787-01  TCGA-S9-A7J2-01  \
# 0  ENSG00000242268          -9.9658           0.2998
# 1  ENSG00000259041          -9.9658          -9.9658
# 2  ENSG00000270112          -3.8160          -3.0469
# 3  ENSG00000167578           5.2998           4.8881
# 4  ENSG00000278814          -9.9658          -9.9658
#
#    GTEX-13QIC-0011-R1a-SM-5O9CJ  TCGA-E1-A7YI-01  TCGA-06-5412-01  \
# 0                       -9.9658          -0.4521          -4.2934
# 1                       -9.9658          -9.9658          -9.9658
# 2                       -1.8314          -0.7346           0.1519
# 3                        6.4989           5.7632           6.1687
# 4                       -9.9658          -9.9658          -9.9658
#
#    TCGA-DU-7302-01  TCGA-DU-A7TI-01  GTEX-N7MS-2526-SM-26GMA  \
# 0          -2.5479          -0.6193                  -0.5756
# 1          -9.9658          -9.9658                  -9.9658
# 2           0.9115          -2.6349                   3.7204
# 3           5.6329           5.8709                   6.0086
# 4          -9.9658          -9.9658                  -9.9658
#
#    GTEX-N7MS-2526-SM-26GMR  ...  TCGA-06-0745-01  \
# 0                  -2.8262  ...          -1.2481
# 1                  -9.9658  ...          -9.9658
# 2                   1.7489  ...           1.2147
# 3                   2.1894  ...           6.0330
# 4                  -9.9658  ...          -9.9658
#
#    GTEX-13G51-0011-R6b-SM-5LZX4  TCGA-TM-A84B-01  \
# 0                       -1.0262           1.1117
# 1                       -9.9658          -9.9658
# 2                       -0.8599           1.8242
# 3                        5.6789           4.6809
# 4                       -9.9658          -9.9658
#
#    GTEX-YFC4-0011-R10a-SM-4SOK5  TCGA-DU-A76O-01  \
# 0                       -0.6416          -9.9658
# 1                       -9.9658          -9.9658
# 2                        1.2576          -6.5064
# 3                        6.5322           6.2263
# 4                       -9.9658          -9.9658
#
#    GTEX-13112-0011-R4b-SM-5DUXL  GTEX-1313W-0011-R1b-SM-5EQ4A  \
# 0                       -2.5479                       -1.5522
# 1                       -9.9658                       -9.9658
# 2                       -1.0862                        0.6880
# 3                        5.5100                        6.1258
# 4                       -9.9658                       -9.9658
#
#    TCGA-CS-4944-01  TCGA-HT-7603-01  GTEX-Q2AG-2826-SM-2HMJQ
# 0          -9.9658          -9.9658                   0.0440
# 1          -9.9658          -9.9658                  -9.9658
# 2          -4.2934           1.0642                   2.5852
# 3           6.6567           6.8560                   5.8110
# 4          -9.9658          -9.9658                  -9.9658
#
# [5 rows x 1840 columns]

# %%
metadata_df = pd.read_csv(
    import_metadata_filepath,
    # index_col='sample_id'
)

print("\nMetadata Shape:", metadata_df.shape)
display(metadata_df.head())
# Out:
# Metadata Shape: (1839, 7)
#          sample_id        detailed_category primary disease or tissue  \
# 0  TCGA-06-0152-02  Glioblastoma Multiforme   Glioblastoma Multiforme
# 1  TCGA-06-0171-02  Glioblastoma Multiforme   Glioblastoma Multiforme
# 2  TCGA-06-0190-02  Glioblastoma Multiforme   Glioblastoma Multiforme
# 3  TCGA-19-1389-02  Glioblastoma Multiforme   Glioblastoma Multiforme
# 4  TCGA-14-0736-02  Glioblastoma Multiforme   Glioblastoma Multiforme
#
#   _primary_site     _sample_type _gender _study
# 0         Brain  Recurrent Tumor    Male   TCGA
# 1         Brain  Recurrent Tumor    Male   TCGA
# 2         Brain  Recurrent Tumor    Male   TCGA
# 3         Brain  Recurrent Tumor    Male   TCGA
# 4         Brain  Recurrent Tumor    Male   TCGA

# %% [markdown]
# ## Prepare samples

# %% [markdown]
# ### label mapping
# - 1 - healthy.
# - 2 - Lower Grade Glioma.
# - 3 - Glioblastoma Multiforme.

# %%
healthy_metadata = metadata_df[(
    (metadata_df['_sample_type'] == 'Normal Tissue')
)].copy()
print(f"Created Healthy group with {len(healthy_metadata)} samples.")
healthy_metadata['label'] = 1

unhealthy_metadata = metadata_df[(
    (metadata_df['_sample_type'] == 'Primary Tumor')
)]
print(f"Created Unhealthy group with {len(unhealthy_metadata)} samples.")

unhealthy_lgg_metadata = unhealthy_metadata[
    unhealthy_metadata['primary disease or tissue'] == 'Brain Lower Grade Glioma'
].copy()
print(f"Created Unhealthy LGG group with {len(unhealthy_lgg_metadata)} samples.")
unhealthy_lgg_metadata['label'] = 2

unhealthy_gbm_metadata = unhealthy_metadata[
    unhealthy_metadata['primary disease or tissue'] == 'Glioblastoma Multiforme'
].copy()
print(f"Created Unhealthy GBM group with {len(unhealthy_gbm_metadata)} samples.")
unhealthy_gbm_metadata['label'] = 3


combined_metadata_df = pd.concat([healthy_metadata, unhealthy_lgg_metadata, unhealthy_gbm_metadata])
combined_metadata_df.info()
# Out:
# Created Healthy group with 1152 samples.
# Created Unhealthy group with 660 samples.
# Created Unhealthy LGG group with 508 samples.
# Created Unhealthy GBM group with 152 samples.
# <class 'pandas.core.frame.DataFrame'>
# Index: 1812 entries, 687 to 164
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   sample_id                  1812 non-null   object
#  1   detailed_category          1812 non-null   object
#  2   primary disease or tissue  1812 non-null   object
#  3   _primary_site              1812 non-null   object
#  4   _sample_type               1812 non-null   object
#  5   _gender                    1812 non-null   object
#  6   _study                     1812 non-null   object
#  7   label                      1812 non-null   int64
# dtypes: int64(1), object(7)
# memory usage: 127.4+ KB

# %%
# --- 1. Create a copy and map labels for plotting ---
plot_df = combined_metadata_df.copy()

# Define the new string labels
label_map = {
    1: 'Healthy',
    2: 'LGG',
    3: 'GBM'
}
plot_df['Diagnosis'] = plot_df['label'].map(label_map)

# --- 2. Create the plot ---
plt.figure(figsize=(8, 6))

# Define the order we want the bars to appear in
plot_order = ['Healthy', 'LGG', 'GBM']

# Define a clear color palette
plot_palette = {
    'Healthy': '#457B9D', 
    'LGG': '#A8DADC', 
    'GBM': '#E63946'
}

sns.countplot(
    x='Diagnosis',
    data=plot_df,
    order=plot_order,
    palette=plot_palette,
    hue='Diagnosis', # We still map hue to get the colors
    legend=False
)

plt.title('Distribution of Samples by Class', fontsize=16)
plt.xlabel('Diagnosis', fontsize=12)
plt.ylabel('Sample Count', fontsize=12)
plt.xticks(fontsize=11)
plt.tight_layout()
plt.show()

# %%
combined_metadata_df
# Out:
#                         sample_id        detailed_category  \
# 687  GTEX-13SLW-0011-R4b-SM-5S2W2         Brain - Amygdala
# 688  GTEX-13RTJ-0011-R4b-SM-5PNX1         Brain - Amygdala
# 689   GTEX-WVLH-0011-R4A-SM-3MJFS         Brain - Amygdala
# 690  GTEX-147GR-0011-R4a-SM-5S2V2         Brain - Amygdala
# 691  GTEX-13N2G-0011-R4b-SM-5MR54         Brain - Amygdala
# ..                            ...                      ...
# 160               TCGA-12-0616-01  Glioblastoma Multiforme
# 161               TCGA-12-3653-01  Glioblastoma Multiforme
# 162               TCGA-06-2569-01  Glioblastoma Multiforme
# 163               TCGA-06-5416-01  Glioblastoma Multiforme
# 164               TCGA-06-2570-01  Glioblastoma Multiforme
#
#     primary disease or tissue _primary_site   _sample_type _gender _study  \
# 687          Brain - Amygdala         Brain  Normal Tissue    Male   GTEX
# 688          Brain - Amygdala         Brain  Normal Tissue    Male   GTEX
# 689          Brain - Amygdala         Brain  Normal Tissue    Male   GTEX
# 690          Brain - Amygdala         Brain  Normal Tissue    Male   GTEX
# 691          Brain - Amygdala         Brain  Normal Tissue    Male   GTEX
# ..                        ...           ...            ...     ...    ...
# 160   Glioblastoma Multiforme         Brain  Primary Tumor  Female   TCGA
# 161   Glioblastoma Multiforme         Brain  Primary Tumor  Female   TCGA
# 162   Glioblastoma Multiforme         Brain  Primary Tumor  Female   TCGA
# 163   Glioblastoma Multiforme         Brain  Primary Tumor  Female   TCGA
# 164   Glioblastoma Multiforme         Brain  Primary Tumor  Female   TCGA
#
#      label
# 687      1
# 688      1
# 689      1
# 690      1
# 691      1
# ..     ...
# 160      3
# 161      3
# 162      3
# 163      3
# 164      3
#
# [1812 rows x 8 columns]

# %%
b_samples_to_keep = combined_metadata_df['sample_id'].tolist()

print(f"Total samples to keep for analysis: {len(b_samples_to_keep)}")
expression_indexed_df = gene_expression_df.set_index('sample_id')
filtered_genes = expression_indexed_df[
    expression_indexed_df.columns.intersection(b_samples_to_keep)
].copy()

print(f"Filtered expression matrix shape: {filtered_genes.shape}")

print("\n--- Pipeline B Complete ---")
print(f"Final `gene` matrix shape: {filtered_genes.shape}")
display(filtered_genes.head())
# Out:
# Total samples to keep for analysis: 1812
# Filtered expression matrix shape: (60498, 1812)
#
# --- Pipeline B Complete ---
# Final `gene` matrix shape: (60498, 1812)
#                  TCGA-19-1787-01  TCGA-S9-A7J2-01  \
# sample_id
# ENSG00000242268          -9.9658           0.2998
# ENSG00000259041          -9.9658          -9.9658
# ENSG00000270112          -3.8160          -3.0469
# ENSG00000167578           5.2998           4.8881
# ENSG00000278814          -9.9658          -9.9658
#
#                  GTEX-13QIC-0011-R1a-SM-5O9CJ  TCGA-E1-A7YI-01  \
# sample_id
# ENSG00000242268                       -9.9658          -0.4521
# ENSG00000259041                       -9.9658          -9.9658
# ENSG00000270112                       -1.8314          -0.7346
# ENSG00000167578                        6.4989           5.7632
# ENSG00000278814                       -9.9658          -9.9658
#
#                  TCGA-06-5412-01  TCGA-DU-7302-01  TCGA-DU-A7TI-01  \
# sample_id
# ENSG00000242268          -4.2934          -2.5479          -0.6193
# ENSG00000259041          -9.9658          -9.9658          -9.9658
# ENSG00000270112           0.1519           0.9115          -2.6349
# ENSG00000167578           6.1687           5.6329           5.8709
# ENSG00000278814          -9.9658          -9.9658          -9.9658
#
#                  GTEX-N7MS-2526-SM-26GMA  GTEX-N7MS-2526-SM-26GMR  \
# sample_id
# ENSG00000242268                  -0.5756                  -2.8262
# ENSG00000259041                  -9.9658                  -9.9658
# ENSG00000270112                   3.7204                   1.7489
# ENSG00000167578                   6.0086                   2.1894
# ENSG00000278814                  -9.9658                  -9.9658
#
#                  GTEX-NPJ7-0011-R6a-SM-2I3G7  ...  TCGA-06-0745-01  \
# sample_id                                     ...
# ENSG00000242268                      -0.5973  ...          -1.2481
# ENSG00000259041                      -9.9658  ...          -9.9658
# ENSG00000270112                      -0.8084  ...           1.2147
# ENSG00000167578                       5.4350  ...           6.0330
# ENSG00000278814                      -9.9658  ...          -9.9658
#
#                  GTEX-13G51-0011-R6b-SM-5LZX4  TCGA-TM-A84B-01  \
# sample_id
# ENSG00000242268                       -1.0262           1.1117
# ENSG00000259041                       -9.9658          -9.9658
# ENSG00000270112                       -0.8599           1.8242
# ENSG00000167578                        5.6789           4.6809
# ENSG00000278814                       -9.9658          -9.9658
#
#                  GTEX-YFC4-0011-R10a-SM-4SOK5  TCGA-DU-A76O-01  \
# sample_id
# ENSG00000242268                       -0.6416          -9.9658
# ENSG00000259041                       -9.9658          -9.9658
# ENSG00000270112                        1.2576          -6.5064
# ENSG00000167578                        6.5322           6.2263
# ENSG00000278814                       -9.9658          -9.9658
#
#                  GTEX-13112-0011-R4b-SM-5DUXL  GTEX-1313W-0011-R1b-SM-5EQ4A  \
# sample_id
# ENSG00000242268                       -2.5479                       -1.5522
# ENSG00000259041                       -9.9658                       -9.9658
# ENSG00000270112                       -1.0862                        0.6880
# ENSG00000167578                        5.5100                        6.1258
# ENSG00000278814                       -9.9658                       -9.9658
#
#                  TCGA-CS-4944-01  TCGA-HT-7603-01  GTEX-Q2AG-2826-SM-2HMJQ
# sample_id
# ENSG00000242268          -9.9658          -9.9658                   0.0440
# ENSG00000259041          -9.9658          -9.9658                  -9.9658
# ENSG00000270112          -4.2934           1.0642                   2.5852
# ENSG00000167578           6.6567           6.8560                   5.8110
# ENSG00000278814          -9.9658          -9.9658                  -9.9658
#
# [5 rows x 1812 columns]

# %% [markdown]
# ## Store data for ease of use

# %%
labels_df = combined_metadata_df.set_index('sample_id').copy()
final_labels_df = labels_df[['label']]

# We add index_label='sample_id' here too for consistency
final_labels_df.to_csv(export_metadata_filepath, index_label='sample_id')
print(f"Labels saved to: {export_metadata_filepath}")
# Out:
# Labels saved to: data/processed/metadata_gbm_lgg_healthy.csv

# %%
gene_T = filtered_genes.T

scaler = StandardScaler()
gene_scaled_array = scaler.fit_transform(gene_T)

# --- 4. Convert Scaled Data Back to DataFrame ---
gene_scaled_df = pd.DataFrame(
    gene_T,
    index=gene_T.index,
    columns=gene_T.columns
)

# We add index_label='sample_id' to name the first column
gene_scaled_df.to_csv(export_expression_filepath, index_label='sample_id')
print(f"Scaled data saved to: {export_expression_filepath}")
# Out:
# Scaled data saved to: data/processed/expression_gbm_lgg_healthy.csv
